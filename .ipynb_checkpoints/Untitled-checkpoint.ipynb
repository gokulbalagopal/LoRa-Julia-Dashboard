# %% [markdown]
# ### Loading Libraries

# %%
using CSV
using DataFrames
using Dates
using Plots

# %% [markdown]
# ### Loading CSV File

# %%
df = CSV.read("//mnt//3fbf694d-d8e0-46c0-903d-69d994241206//mintsData//raw//b827eb52fc29//47cb5580002e004a//47cb5580002e004a_2021-06-17.csv",DataFrame)
df.dateTime = DateTime.(df.dateTime,"yyyy-mm-dd HH:MM:SS")
df_size = size(df)
df_col_name = names(df)
df_col_type = eltype.(eachcol(df))
# Out:
# 31-element Vector{DataType}:
#  DateTime
#  String
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Int64
#  Float64
#  Float64
#  ⋮
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Float64
#  Int64
#  Float64
#  Float64

# %%
head_df = first(df,5)
# Out:
# 5×31 DataFrame
#  Row │ dateTime             id                NH3      CO       NO2      C3H8  ⋯
#      │ DateTime             String            Float64  Float64  Float64  Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 2021-06-17T00:00:19  47cb5580002e004a     0.14      0.0     4.47      0 ⋯
#    2 │ 2021-06-17T00:01:00  47cb5580002e004a     0.14      0.0     4.47      0
#    3 │ 2021-06-17T00:01:41  47cb5580002e004a     0.14      0.0     4.47      0
#    4 │ 2021-06-17T00:02:22  47cb5580002e004a     0.14      0.0     4.47      0
#    5 │ 2021-06-17T00:04:06  47cb5580002e004a     0.14      0.0     4.47      0 ⋯
#                                                               26 columns omitted

# %%
plotly()
plot_array = Any[]
for col in df_col_name[3:8]
    push!(plot_array,plot(df.dateTime, df[!,col], legend = false, xlabel = "Date Time", ylabel = col, label = col))
end
print(plot(plot_array...,layout=length(plot_array)))

# %%
plotly()
plot_array = Any[]
for col in df_col_name[3:8]
    push!(plot_array,plot(df.dateTime, df[!,col], legend = false, xlabel = "Date Time", ylabel = col, label = col))
end
print(plot(plot_array...,layout=length(plot_array)))
# Out:
#     <div id="ce56bffe-d4d9-423c-a787-78b959b7ba0e" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-1.57.1.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         var PLOT = document.getElementById('ce56bffe-d4d9-423c-a787-78b959b7ba0e');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             6.3759571219e13,
#             6.375957126e13,
#             6.3759571301e13,
#             6.3759571342e13,
#             6.3759571446e13,
#             6.3759571486e13,
#             6.3759571527e13,
#             6.3759571568e13,
#             6.3759571608e13,
#             6.3759571649e13,
#             6.3759571731e13,
#             6.3759571771e13,
#             6.3759571812e13,
#             6.3759571893e13,
# ...

# %%
print(df_col_name)
# Out:
# ["dateTime", "id", "NH3", "CO", "NO2", "C3H8", "C4H10", "CH4", "H2", "C2H5OH", "P1_lpo", "P1_ratio", "P1_conc", "P2_lpo", "P2_ratio", "P2_conc", "Temperature", "Pressure", "Humidity", "gpsTime", "Latitude", "Longitude", "shuntVoltageBat", "busVoltageBat", "currentBat", "shuntVoltageSol", "busVoltageSol", "currentSol", "CO2", "SCD30_temperature", "SCD30_humidity"]
